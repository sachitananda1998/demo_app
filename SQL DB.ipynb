# %%
# !pip install mysql-connector-python
# Out:
# ...
#   Using cached mysql_connector_python-8.3.0-cp312-cp312-win_amd64.whl.metadata (2.0 kB)
# Using cached mysql_connector_python-8.3.0-cp312-cp312-win_amd64.whl (15.4 MB)
# ...

# %%
import mysql.connector
mydb = mysql.connector.connect(
 host="localhost",
 user="root",
 password="",)
print(mydb)
mycursor = mydb.cursor(buffered=True)

# %%
mycursor.execute("create database Situn")

# %%
import mysql.connector
connection = mysql.connector.connect(
  host = "gateway01.ap-southeast-1.prod.aws.tidbcloud.com",
  port = 4000,
  user = "DGA4By71d5J9jwq.root",
  password = "56rMxVI7SQhWRcoT")
mycursor = connection.cursor(buffered=True)

# %%
mycursor.execute("show databases")
for i in mycursor:
    print(i)
#print(*mycursor)
# Out:
# ('a',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('phpmyadmin',)
# ('sachin',)
# ('sat',)
# ('situn',)
# ('test',)

# %%
mycursor.execute("drop database Today")

# %%
m = input("Please enter the name of the databases seperated by space : ").split()
for i in m:
    mycursor.execute(f"CREATE DATABASE {i}")

# %%
mycursor.execute("show databases")
for i in mycursor:
    print(i)
# Out:
# ('a',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('phpmyadmin',)
# ('sachin',)
# ('sat',)
# ('situn',)
# ('test',)

# %%
mycursor.execute("CREATE TABLE Cric.stats (name VARCHAR(40),number VARCHAR(10))")

# %%
mycursor.execute("INSERT INTO Cric.stats(`name`, `number`) VALUES ('Samhita Jena', '7550120559');")

# %%
connection.commit()

# %%
mycursor.execute("CREATE TABLE sachin.student1 (Name varchar(40), student_id varchar(20))")

# %%
mycursor.execute("INSERT INTO sachin.student1 ('Name','student_id') VALUES ('Sachitananda Jena', '1234');")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\sachi\OneDrive\Desktop\VS Code\guvi\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MariaDB server version for the right syntax to use near ''Name','student_id') VALUES ('Sachitananda Jena', '1234')' at line 1
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import mysql.connector
mydb = mysql.connector.connect(
 host="localhost",
 user="root",
 password="",)
print(mydb)
mycursor = mydb.cursor(buffered=True)

# %%
mycursor.execute("show databases")
for i in mycursor:
    print(i)
# Out:
# ('a',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('phpmyadmin',)
# ('sachin',)
# ('sat',)
# ('situn',)
# ('test',)

# %%
mycursor.execute("CREATE TABLE test.lucky (salary INT(6),weight DECIMAL(5,3),insurance BOOLEAN)")

# %%
mycursor.execute("ALTER TABLE test.lucky ADD covid_status VARCHAR(5)")

# %%
mydb.commit()

# %%
mycursor.execute("ALTER TABLE test.lucky ADD vaccine VARCHAR(5) AFTER salary")

# %%
mydb.commit()

# %%
mycursor.execute("ALTER TABLE test.lucky ADD Date VARCHAR(5) FIRST")

# %%
mydb.commit()

# %%
mycursor.execute("ALTER TABLE test.lucky DROP COLUMN Date")

# %%
mydb.commit()

# %%
mycursor.execute("ALTER TABLE test.lucky CHANGE COLUMN salary percentage INT")

# %%
mydb.commit()

# %%
mycursor.execute("ALTER TABLE test.lucky MODIFY percentage VARCHAR(20)")

# %%
mydb.commit()

# %%
mycursor.execute("USE test")

# %%
mycursor.execute("CREATE TABLE date123 (datein DATE)")

# %%
mydb.commit()

# %%
mycursor.execute("INSERT INTO date123 (datein) VALUES ( CURDATE())")
mycursor.execute("INSERT INTO date123 (datein) VALUES ( CURRENT_DATE())")
mycursor.execute("INSERT INTO date123 (datein) VALUES (CURTIME())")
mycursor.execute("INSERT INTO date123 (datein) VALUES (CURRENT_TIMESTAMP())")
mycursor.execute("INSERT INTO date123 (datein) VALUES (CURRENT_TIME())")
mycursor.execute("INSERT INTO date123 (datein) VALUES (NOW())")
mydb.commit()


#whatever date format given into DATE datatypw will consider in the sameway

# %%
mydb.commit()

# %%
mycursor.execute("CREATE TABLE datestrin (datein VARCHAR(255))")

# %%
mycursor.execute("INSERT INTO datestrin (datein) VALUES ( CURDATE())")
mycursor.execute("INSERT INTO datestrin (datein) VALUES ( CURRENT_DATE())")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (CURTIME())")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (CURRENT_TIMESTAMP())")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (CURRENT_TIME())")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (NOW())")#date and time
mycursor.execute("INSERT INTO datestrin (datein) VALUES (MONTHNAME(NOW()))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (DAYNAME(NOW()))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (HOUR(NOW()))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (MINUTE(NOW()))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (DATE_ADD(NOW(),INTERVAL -10 DAY))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (DATE_FORMAT(NOW(),'%W %D %M %Y %T %H'))")

# %%
mycursor.execute("INSERT INTO datestrin (datein) VALUES (UTC_DATE())")#UTC_TIME,UTC_TIMESTAMP
mydb.commit()

# %%
mycursor.execute("SELECT * FROM test.patients")

# %%
print(*mycursor)
# Out:
# (6, 148, 72, 35, 0, Decimal('33.6'), Decimal('0.627'), 50, 1) (1, 85, 66, 29, 0, Decimal('26.6'), Decimal('0.351'), 31, 0) (8, 183, 64, 0, 0, Decimal('23.3'), Decimal('0.672'), 32, 1) (1, 89, 66, 23, 94, Decimal('28.1'), Decimal('0.167'), 21, 0) (0, 137, 40, 35, 168, Decimal('43.1'), Decimal('2.288'), 33, 1) (5, 116, 74, 0, 0, Decimal('25.6'), Decimal('0.201'), 30, 0) (3, 78, 50, 32, 88, Decimal('31.0'), Decimal('0.248'), 26, 1) (10, 115, 0, 0, 0, Decimal('35.3'), Decimal('0.134'), 29, 0) (2, 197, 70, 45, 543, Decimal('30.5'), Decimal('0.158'), 53, 1) (8, 125, 96, 0, 0, Decimal('0.0'), Decimal('0.232'), 54, 1) (4, 110, 92, 0, 0, Decimal('37.6'), Decimal('0.191'), 30, 0) (10, 168, 74, 0, 0, Decimal('38.0'), Decimal('0.537'), 34, 1) (10, 139, 80, 0, 0, Decimal('27.1'), Decimal('1.441'), 57, 0) (1, 189, 60, 23, 846, Decimal('30.1'), Decimal('0.398'), 59, 1) (5, 166, 72, 19, 175, Decimal('25.8'), Decimal('0.587'), 51, 1) (7, 100, 0, 0, 0, Decimal('30.0'), Decimal('0.484'), 32, 1) (0, 118
# ...

# %%
# !pip install tabulate

# %%
mycursor.execute("SELECT * FROM test.patients")
out=mycursor.fetchall()
from tabulate import tabulate
print(mycursor.description)
#print(mycursor.description) prints column description
#print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# [('Pregnancies', 3, None, None, None, None, 1, 32768, 63), ('Glucose', 3, None, None, None, None, 1, 32768, 63), ('BloodPressure', 3, None, None, None, None, 1, 32768, 63), ('SkinThickness', 3, None, None, None, None, 1, 32768, 63), ('Insulin', 3, None, None, None, None, 1, 32768, 63), ('BMI', 246, None, None, None, None, 1, 32768, 63), ('DiabetesPedigreeFunction', 246, None, None, None, None, 1, 32768, 63), ('Age', 3, None, None, None, None, 1, 32768, 63), ('Outcome', 3, None, None, None, None, 1, 32768, 63)]

# %%
mycursor.execute("SELECT * FROM test.patients")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             6 |       148 |              72 |              35 |         0 |  33.6 |                      0.627 |    50 |         1 |
# |             1 |        85 |              66 |              29 |         0 |  26.6 |                      0.351 |    31 |         0 |
# |             8 |       183 |              64 |               0 |         0 |  23.3 |                      0.672 |    32 |         1 |
# |             1 |        89 |              66 |              23 |        94 |  28.1 |                      0.167 |    21 |         0 |
# ...

# %%
mycursor.execute("SELECT BMI,Age FROM test.patients")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+-------+
# |   BMI |   Age |
# |-------+-------|
# |  33.6 |    50 |
# |  26.6 |    31 |
# |  23.3 |    32 |
# |  28.1 |    21 |
# |  43.1 |    33 |
# |  25.6 |    30 |
# |  31   |    26 |
# |  35.3 |    29 |
# |  30.5 |    53 |
# |   0   |    54 |
# |  37.6 |    30 |
# |  38   |    34 |
# |  27.1 |    57 |
# |  30.1 |    59 |
# |  25.8 |    51 |
# |  30   |    32 |
# |  45.8 |    31 |
# |  29.6 |    31 |
# |  43.3 |    33 |
# |  34.6 |    32 |
# |  39.3 |    27 |
# |  35.4 |    50 |
# |  39.8 |    41 |
# |  29   |    29 |
# |  36.6 |    51 |
# |  31.1 |    41 |
# |  39.4 |    43 |
# |  23.2 |    22 |
# |  22.2 |    57 |
# |  34.1 |    38 |
# |  36   |    60 |
# |  31.6 |    28 |
# |  24.8 |    22 |
# |  19.9 |    28 |
# |  27.6 |    45 |
# |  24   |    33 |
# |  33.2 |    35 |
# |  32.9 |    46 |
# |  38.2 |    27 |
# |  37.1 |    56 |
# |  34   |    26 |
# |  40.2 |    37 |
# |  22.7 |    48 |
# |  45.4 |    54 |
# |  27.4 |    40 |
# |  42   |    25 |
# |  29.7 |    29 |
# ...

# %%
mycursor.execute("SELECT BMI+Age as Data FROM test.patients")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +--------+
# |   Data |
# |--------|
# |   83.6 |
# |   57.6 |
# |   55.3 |
# |   49.1 |
# |   76.1 |
# |   55.6 |
# |   57   |
# |   64.3 |
# |   83.5 |
# |   54   |
# |   67.6 |
# |   72   |
# |   84.1 |
# |   89.1 |
# |   76.8 |
# |   62   |
# |   76.8 |
# |   60.6 |
# |   76.3 |
# |   66.6 |
# |   66.3 |
# |   85.4 |
# |   80.8 |
# |   58   |
# |   87.6 |
# |   72.1 |
# |   82.4 |
# |   45.2 |
# |   79.2 |
# |   72.1 |
# |   96   |
# |   59.6 |
# |   46.8 |
# |   47.9 |
# |   72.6 |
# |   57   |
# |   68.2 |
# |   78.9 |
# |   65.2 |
# |   93.1 |
# |   60   |
# |   77.2 |
# |   70.7 |
# |   99.4 |
# |   67.4 |
# |   67   |
# |   58.7 |
# |   50   |
# |   70.1 |
# |   24   |
# |   41.4 |
# |   50.2 |
# |   54.4 |
# |   91.7 |
# |   76.7 |
# |   44   |
# |   78.7 |
# |   77.8 |
# |   84.5 |
# |   63.5 |
# |   21   |
# |   71.9 |
# |   61   |
# |   49.4 |
# |   74.8 |
# |   61   |
# |   70.5 |
# |   96.7 |
# |   44.6 |
# |   55.9 |
# |   60.9 |
# |   54.6 |
# |   85.4 |
# ...

# %%
mycursor.execute("SELECT BMI,Age FROM test.patients LIMIT 5")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+-------+
# |   BMI |   Age |
# |-------+-------|
# |  33.6 |    50 |
# |  26.6 |    31 |
# |  23.3 |    32 |
# |  28.1 |    21 |
# |  43.1 |    33 |
# +-------+-------+

# %%
mycursor.execute("SELECT * FROM patients WHERE OUTCOME=1")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             6 |       148 |              72 |              35 |         0 |  33.6 |                      0.627 |    50 |         1 |
# |             8 |       183 |              64 |               0 |         0 |  23.3 |                      0.672 |    32 |         1 |
# |             0 |       137 |              40 |              35 |       168 |  43.1 |                      2.288 |    33 |         1 |
# |             3 |        78 |              50 |              32 |        88 |  31   |                      0.248 |    26 |         1 |
# ...

# %%
mycursor.execute("SELECT * FROM test.patients WHERE OUTCOME=1 AND AGE < 30")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             3 |        78 |              50 |              32 |        88 |  31   |                      0.248 |    26 |         1 |
# |             9 |       119 |              80 |              35 |         0 |  29   |                      0.263 |    29 |         1 |
# |             3 |       158 |              76 |              36 |       245 |  31.6 |                      0.851 |    28 |         1 |
# |             2 |        90 |              68 |              42 |         0 |  38.2 |                      0.503 |    27 |         1 |
# ...

# %%
mycursor.execute("SELECT * FROM test.patients WHERE OUTCOME=1 OR AGE < 30")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             6 |       148 |              72 |              35 |         0 |  33.6 |                      0.627 |    50 |         1 |
# |             8 |       183 |              64 |               0 |         0 |  23.3 |                      0.672 |    32 |         1 |
# |             1 |        89 |              66 |              23 |        94 |  28.1 |                      0.167 |    21 |         0 |
# |             0 |       137 |              40 |              35 |       168 |  43.1 |                      2.288 |    33 |         1 |
# ...

# %%
mycursor.execute("SELECT * FROM test.patients WHERE (GLUCOSE > 140 AND OUTCOME = 1) or (BMI > 25 AND (GLUCOSE > 130 AND GLUCOSE <140))")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             6 |       148 |              72 |              35 |         0 |  33.6 |                      0.627 |    50 |         1 |
# |             8 |       183 |              64 |               0 |         0 |  23.3 |                      0.672 |    32 |         1 |
# |             0 |       137 |              40 |              35 |       168 |  43.1 |                      2.288 |    33 |         1 |
# |             2 |       197 |              70 |              45 |       543 |  30.5 |                      0.158 |    53 |         1 |
# ...

# %%
mycursor.execute("SELECT * FROM test.patients WHERE PREGNANCIES IN (5,8,2,3)")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             8 |       183 |              64 |               0 |         0 |  23.3 |                      0.672 |    32 |         1 |
# |             5 |       116 |              74 |               0 |         0 |  25.6 |                      0.201 |    30 |         0 |
# |             3 |        78 |              50 |              32 |        88 |  31   |                      0.248 |    26 |         1 |
# |             2 |       197 |              70 |              45 |       543 |  30.5 |                      0.158 |    53 |         1 |
# ...

# %%
mycursor.execute("SELECT * FROM test.patients WHERE PREGNANCIES NOT IN (5,8,2,3)")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             6 |       148 |              72 |              35 |         0 |  33.6 |                      0.627 |    50 |         1 |
# |             1 |        85 |              66 |              29 |         0 |  26.6 |                      0.351 |    31 |         0 |
# |             1 |        89 |              66 |              23 |        94 |  28.1 |                      0.167 |    21 |         0 |
# |             0 |       137 |              40 |              35 |       168 |  43.1 |                      2.288 |    33 |         1 |
# ...

# %%
mycursor.execute("SELECT * FROM test.patients WHERE AGE BETWEEN 21 AND 30")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             1 |        89 |              66 |              23 |        94 |  28.1 |                      0.167 |    21 |         0 |
# |             5 |       116 |              74 |               0 |         0 |  25.6 |                      0.201 |    30 |         0 |
# |             3 |        78 |              50 |              32 |        88 |  31   |                      0.248 |    26 |         1 |
# |            10 |       115 |               0 |               0 |         0 |  35.3 |                      0.134 |    29 |         0 |
# ...

# %%
mycursor.execute("USE test")

# %%
mydb.commit()

# %%
mycursor.execute("SELECT * FROM apple_products")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +--------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------+---------+--------------+--------+-----------------------+---------------------+---------------------+------------------+---------------+-------+
# | Product Name                                                             | Product URL                                                                                                                        | Brand   |   Sale Price |    Mrp |   Discount Percentage |   Number Of Ratings |   Number Of Reviews | Upc              |   Star Rating | Ram   |
# ...

# %%
mycursor.execute("SELECT * FROM apple_products WHERE UPC LIKE '%MOBEXRGV%'")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +------------------------------------------+--------------------------------------------------------------------------------------------------------+---------+--------------+-------+-----------------------+---------------------+---------------------+------------------+---------------+-------+
# | Product Name                             | Product URL                                                                                            | Brand   |   Sale Price |   Mrp |   Discount Percentage |   Number Of Ratings |   Number Of Reviews | Upc              |   Star Rating | Ram   |
# |------------------------------------------+--------------------------------------------------------------------------------------------------------+---------+--------------+-------+-----------------------+---------------------+---------------------+------------------+---------------+-------|
# ...

# %%
mycursor.execute(" SELECT * FROM `apple_products` ORDER BY `apple_products`.`Product Name` ASC ")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +--------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------+---------+--------------+--------+-----------------------+---------------------+---------------------+------------------+---------------+-------+
# | Product Name                                                             | Product URL                                                                                                                        | Brand   |   Sale Price |    Mrp |   Discount Percentage |   Number Of Ratings |   Number Of Reviews | Upc              |   Star Rating | Ram   |
# ...

# %%
mycursor.execute("SELECT COUNT(*) FROM patients")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +------------+
# |   COUNT(*) |
# |------------|
# |        768 |
# +------------+

# %%
mycursor.execute("SELECT COUNT(*) FROM patients WHERE OUTCOME = 1")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +------------+
# |   COUNT(*) |
# |------------|
# |        268 |
# +------------+

# %%
mycursor.execute("SELECT * FROM patients WHERE AGE =81")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             9 |       134 |              74 |              33 |        60 |  25.9 |                       0.46 |    81 |         0 |
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+

# %%
mycursor.execute("SELECT * FROM patients WHERE AGE =(SELECT MAX(AGE) FROM patients)")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             9 |       134 |              74 |              33 |        60 |  25.9 |                       0.46 |    81 |         0 |
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+

# %%
mycursor.execute("SELECT * FROM patients WHERE BMI =(SELECT MIN(BMI) FROM patients)")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             8 |       125 |              96 |               0 |         0 |     0 |                      0.232 |    54 |         1 |
# |             7 |       105 |               0 |               0 |         0 |     0 |                      0.305 |    24 |         0 |
# |             2 |        84 |               0 |               0 |         0 |     0 |                      0.304 |    21 |         0 |
# |             2 |        74 |               0 |               0 |         0 |     0 |                      0.102 |    22 |         0 |
# ...

# %%
mycursor.execute("SELECT SUM(AGE)/COUNT(AGE) FROM patients WHERE OUTCOME =1")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-----------------------+
# |   SUM(AGE)/COUNT(AGE) |
# |-----------------------|
# |               37.0672 |
# +-----------------------+

# %%
mycursor.execute("SELECT AVG(AGE) FROM patients WHERE OUTCOME =1")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +------------+
# |   AVG(AGE) |
# |------------|
# |    37.0672 |
# +------------+

# %%
mycursor.execute("SELECT MIN(AGE) AS LOWEST , MAX(AGE) AS HIGHEST  FROM patients WHERE OUTCOME =1")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +----------+-----------+
# |   LOWEST |   HIGHEST |
# |----------+-----------|
# |       21 |        70 |
# +----------+-----------+

# %%
mycursor.execute("SELECT * FROM patients ORDER BY AGE DESC")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             9 |       134 |              74 |              33 |        60 |  25.9 |                      0.46  |    81 |         0 |
# |             2 |       119 |               0 |               0 |         0 |  19.6 |                      0.832 |    72 |         0 |
# |             4 |       145 |              82 |              18 |         0 |  32.5 |                      0.235 |    70 |         1 |
# |             5 |       136 |              82 |               0 |         0 |   0   |                      0.64  |    69 |         0 |
# ...

# %%
mycursor.execute("SELECT * FROM patients ORDER BY AGE ASC, GLUCOSE DESC")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             0 |       177 |              60 |              29 |       478 |  34.6 |                      1.072 |    21 |         1 |
# |             0 |       151 |              90 |              46 |         0 |  42.1 |                      0.371 |    21 |         1 |
# |             1 |       143 |              74 |              22 |        61 |  26.2 |                      0.256 |    21 |         0 |
# |             2 |       142 |              82 |              18 |        64 |  24.7 |                      0.761 |    21 |         0 |
# ...

# %%
import mysql.connector
mydb = mysql.connector.connect(
 host="localhost",
 user="root",
 password="",)
print(mydb)
mycursor = mydb.cursor(buffered=True)

# %%
mycursor.execute("USE test")

# %%
mycursor.execute("SELECT * FROM patients WHERE AGE > 20 ORDER BY AGE ASC, GLUCOSE DESC")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             0 |       177 |              60 |              29 |       478 |  34.6 |                      1.072 |    21 |         1 |
# |             0 |       151 |              90 |              46 |         0 |  42.1 |                      0.371 |    21 |         1 |
# |             1 |       143 |              74 |              22 |        61 |  26.2 |                      0.256 |    21 |         0 |
# |             2 |       142 |              82 |              18 |        64 |  24.7 |                      0.761 |    21 |         0 |
# ...

# %%
mycursor.execute("SELECT pregnancies,count(*) FROM patients GROUP BY pregnancies ")

# %%
mycursor.execute("SELECT pregnancies,count(*) FROM patients GROUP BY pregnancies ")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+------------+
# |   pregnancies |   count(*) |
# |---------------+------------|
# |             0 |        111 |
# |             1 |        135 |
# |             2 |        103 |
# |             3 |         75 |
# |             4 |         68 |
# |             5 |         57 |
# |             6 |         50 |
# |             7 |         45 |
# |             8 |         38 |
# |             9 |         28 |
# |            10 |         24 |
# |            11 |         11 |
# |            12 |          9 |
# |            13 |         10 |
# |            14 |          2 |
# |            15 |          1 |
# |            17 |          1 |
# +---------------+------------+

# %%
mycursor.execute("SELECT outcome,count(*) FROM patients GROUP BY outcome")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-----------+------------+
# |   outcome |   count(*) |
# |-----------+------------|
# |         0 |        500 |
# |         1 |        268 |
# +-----------+------------+

# %%
mycursor.execute("SELECT outcome,MIN(insulin) as minins ,MAX(insulin) as maxins from patients group by outcome")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-----------+----------+----------+
# |   outcome |   minins |   maxins |
# |-----------+----------+----------|
# |         0 |        0 |      744 |
# |         1 |        0 |      846 |
# +-----------+----------+----------+

# %%
mycursor.execute("SELECT pregnancies, MAX(Age) FROM patients GROUP BY pregnancies ORDER BY 1 DESC")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+------------+
# |   pregnancies |   MAX(Age) |
# |---------------+------------|
# |            17 |         47 |
# |            15 |         43 |
# |            14 |         46 |
# |            13 |         57 |
# |            12 |         62 |
# |            11 |         51 |
# |            10 |         63 |
# |             9 |         81 |
# |             8 |         68 |
# |             7 |         61 |
# |             6 |         66 |
# |             5 |         69 |
# |             4 |         70 |
# |             3 |         63 |
# |             2 |         72 |
# |             1 |         62 |
# |             0 |         67 |
# +---------------+------------+

# %%
mycursor.execute("SELECT pregnancies, MAX(Age) FROM patients GROUP BY pregnancies having MAX(AGE) > 60")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+------------+
# |   pregnancies |   MAX(Age) |
# |---------------+------------|
# |             0 |         67 |
# |             1 |         62 |
# |             2 |         72 |
# |             3 |         63 |
# |             4 |         70 |
# |             5 |         69 |
# |             6 |         66 |
# |             7 |         61 |
# |             8 |         68 |
# |             9 |         81 |
# |            10 |         63 |
# |            12 |         62 |
# +---------------+------------+

# %%
mycursor.execute(
        '''SELECT CASE 
         WHEN bmi < 18.5 THEN 'Underweight' 
         WHEN bmi BETWEEN 18.5 AND 24.9 THEN 'Normal' 
         WHEN bmi BETWEEN 25 AND 29.9 THEN 'Overweight' 
        ELSE 'Obese' 
         END 
         AS bmi_category, 
         COUNT(*) AS patient_count 
         FROM patients 
         GROUP BY bmi_category''')
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +----------------+-----------------+
# | bmi_category   |   patient_count |
# |----------------+-----------------|
# | Normal         |             102 |
# | Obese          |             472 |
# | Overweight     |             179 |
# | Underweight    |              15 |
# +----------------+-----------------+

# %%
mycursor.execute("""
   SELECT Age, Pregnancies, AVG(age) OVER (PARTITION BY Pregnancies ORDER BY Age DESC) as Countw
   FROM patients
""")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+---------------+----------+
# |   Age |   Pregnancies |   Countw |
# |-------+---------------+----------|
# |    67 |             0 |  67      |
# |    65 |             0 |  66      |
# |    62 |             0 |  64.6667 |
# |    59 |             0 |  63.25   |
# |    58 |             0 |  62.2    |
# |    52 |             0 |  60.5    |
# |    46 |             0 |  56.875  |
# |    46 |             0 |  56.875  |
# |    44 |             0 |  54.3    |
# |    44 |             0 |  54.3    |
# |    41 |             0 |  53.0909 |
# |    38 |             0 |  51.8333 |
# |    36 |             0 |  50.6154 |
# |    35 |             0 |  48.5333 |
# |    35 |             0 |  48.5333 |
# |    33 |             0 |  46.7059 |
# |    33 |             0 |  46.7059 |
# |    32 |             0 |  45.1579 |
# |    32 |             0 |  45.1579 |
# |    31 |             0 |  42.6957 |
# |    31 |             0 |  42.6957 |
# |    31 |             0 |  42.6957 |
# ...

# %%
#RANK
mycursor.execute("""
   SELECT Age, Pregnancies, BloodPressure,
          DENSE_RANK() OVER (PARTITION BY Pregnancies ORDER BY BloodPressure DESC) as Rank
   FROM patients
""")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+---------------+-----------------+--------+
# |   Age |   Pregnancies |   BloodPressure |   Rank |
# |-------+---------------+-----------------+--------|
# |    26 |             0 |             110 |      1 |
# |    41 |             0 |             104 |      2 |
# |    35 |             0 |             100 |      3 |
# |    21 |             0 |              96 |      4 |
# |    26 |             0 |              94 |      5 |
# |    23 |             0 |              90 |      6 |
# |    23 |             0 |              90 |      6 |
# |    46 |             0 |              90 |      6 |
# |    21 |             0 |              90 |      6 |
# |    35 |             0 |              90 |      6 |
# |    29 |             0 |              88 |      7 |
# |    38 |             0 |              88 |      7 |
# |    21 |             0 |              88 |      7 |
# |    31 |             0 |              88 |      7 |
# |    32 |             0 |              88 |      7 |
# ...

# %%
#DENSE RANK
mycursor.execute("""
   SELECT Age, Pregnancies, BloodPressure,
          RANK() OVER (PARTITION BY Pregnancies ORDER BY BloodPressure DESC) as Rank
   FROM patients
""")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+---------------+-----------------+--------+
# |   Age |   Pregnancies |   BloodPressure |   Rank |
# |-------+---------------+-----------------+--------|
# |    26 |             0 |             110 |      1 |
# |    41 |             0 |             104 |      2 |
# |    35 |             0 |             100 |      3 |
# |    21 |             0 |              96 |      4 |
# |    26 |             0 |              94 |      5 |
# |    23 |             0 |              90 |      6 |
# |    23 |             0 |              90 |      6 |
# |    46 |             0 |              90 |      6 |
# |    21 |             0 |              90 |      6 |
# |    35 |             0 |              90 |      6 |
# |    29 |             0 |              88 |     11 |
# |    38 |             0 |              88 |     11 |
# |    21 |             0 |              88 |     11 |
# |    31 |             0 |              88 |     11 |
# |    32 |             0 |              88 |     11 |
# ...

# %%
mycursor.execute("CREATE TABLE stu1 (no INTEGER,name TEXT NOT NULL,school VARCHAR(20))")

# %%
a=input("enter name")
b=input("enter age")
query="INSERT INTO test.stu1 (no,name,school) VALUES (%s,%s,%s)"
mycursor.execute(query,(a,b,None))
mydb.commit()

# %%
mycursor.execute("INSERT INTO stu1 (no,name,school) VALUES (123,'A','GUVI')")

# %%
mydb.commit()

# %%
mycursor.execute("SELECT * FROM test.stu1")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +------+--------+----------+
# |   no | name   | school   |
# |------+--------+----------|
# |  123 | A      | GUVI     |
# |    1 | Guvi   |          |
# +------+--------+----------+

# %%
mydb.commit()

# %%
mycursor.execute("INSERT INTO stu1 (no,name,school) VALUES (2, NONE, 'SQL')")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\sachi\OneDrive\Desktop\VS Code\guvi\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Unknown column 'NONE' in 'field list'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 mycursor.execute("INSERT INTO stu1 (no,name,school) VALUES (2, NONE, 'SQL')")
#
# ...

# %%
#unique and check
mycursor.execute("CREATE TABLE test.u (no INTEGER,name TEXT UNIQUE,school VARCHAR(20),age INT CHECK(age<18)) ")

# %%
a=input()
b=input()
c=input()
d=input()
query="INSERT INTO test.u (no,name,school,age) VALUES (%s,%s,%s,%s)"
mycursor.execute(query,(a,b,c,d))
mydb.commit()
#duplicate entry error
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\sachi\OneDrive\Desktop\VS Code\guvi\Lib\site-packages\mysql\connector\connection_cext.py:661, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     660         query = query.encode("utf-8")
# --> 661     self._cmysql.query(
#     662         query,
#     663         raw=raw,
#     664         buffered=buffered,
#     665         raw_as_string=raw_as_string,
#     666         query_attrs=self.query_attrs,
#     667     )
#     668 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Duplicate entry 'Sachin' for key 'name'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[13], line 6
#       4 d=input()
# ...

# %%
print("INSERT INTO test.u (name,age) VALUES (%s,%s)"%(1,2))
print("INSERT INTO test.u (name,age) VALUES ({name},{age})".format(name="nirmal",age=12))

print(f"INSERT INTO test.u (name,age) VALUES ({name},{age})")
