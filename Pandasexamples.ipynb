# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
s = pd.Series([1,2,3,4],index=['a','b','c','d'])
print (s)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
import pandas as pd
import numpy as np
data = {'a' : 0., 'b' : 1., 'c' : 2.,'d':3.,'e':4.}
s = pd.Series(data)
print (s)
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
s[['a','b','d']]
# Out:
# a    0.0
# b    1.0
# d    3.0
# dtype: float64

# %%
import pandas as pd
data = {'Name':['syed', 'Jack', 'ram', 'Ricky'],'Age':[28,34,29,42]}
df = pd.DataFrame(data)
print (df)
# Out:
#     Name  Age
# 0   syed   28
# 1   Jack   34
# 2    ram   29
# 3  Ricky   42

# %%
import pandas as pd
data = {'year': [10, 11, 22, 11, 12, 10, 11, 12],
           'team': ['CSK', 'MI', 'MI', 'SRH', 'KKR', 'CSK','CSK', 'CSK'],
           'wins': [11, 8, 10, 15, 11, 6, 10, 4],
           'losses': [5, 8, 6, 1, 5, 10, 6, 12]}
ipl = pd.DataFrame(data)
print (ipl)
# Out:
#    year team  wins  losses
# 0    10  CSK    11       5
# 1    11   MI     8       8
# 2    22   MI    10       6
# 3    11  SRH    15       1
# 4    12  KKR    11       5
# 5    10  CSK     6      10
# 6    11  CSK    10       6
# 7    12  CSK     4      12

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    8 non-null      int64
#  1   team    8 non-null      object
#  2   wins    8 non-null      int64
#  3   losses  8 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 388.0+ bytes

# %%
type(ipl)
# Out:
# pandas.core.frame.DataFrame

# %%
ipl.describe()
# Out:
#               year       wins     losses
# count     8.000000   8.000000   8.000000
# mean   2011.125000   9.375000   6.625000
# std       0.834523   3.377975   3.377975
# min    2010.000000   4.000000   1.000000
# 25%    2010.750000   7.500000   5.000000
# 50%    2011.000000  10.000000   6.000000
# 75%    2012.000000  11.000000   8.500000
# max    2012.000000  15.000000  12.000000

# %%
ipl[['team','wins']]
# Out:
#   team  wins
# 0  CSK    11
# 1   MI     8
# 2   MI    10
# 3  SRH    15
# 4  KKR    11
# 5  CSK     6
# 6  CSK    10
# 7  CSK     4

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/165.5 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/165.5 kB 435.7 kB/s eta 0:00:01
#      -------------------- ---------------- 92.2/165.5 kB 751.6 kB/s eta 0:00:01
#      -------------------------------------- 165.5/165.5 kB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.2/8.0 MB 4.8 MB/s eta 0:00:02
#    -- ------------------------------------- 0.5/8.0 MB 5.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/8.0 MB 7.3 MB/s eta 0:00:01
#    --------- ------------------------------ 1.8/8.0 MB 9.7 MB/s eta 0:00:01
#    ------------- -------------------------- 2.7/8.0 MB 11.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.4/8.0 MB 12.1 MB/s eta 0:00:01
# ...

# %%
ipl['wins'].plot()
# Out:
# <Axes: >

# %%
ipl.boxplot()
# Out:
# <Axes: >

# %%
ipl.plot()
# Out:
# <Axes: >

# %%
ipl.plot.line(y="wins")
# Out:
# <Axes: >

# %%
ipl.plot.pie(y="losses")
# Out:
# <Axes: ylabel='losses'>

# %%
#print(ipl.iloc[0:2])
#print(ipl.iloc[2:])
#print(ipl.iloc[:4])
#print(ipl.iloc[0:6])


#print(ipl.iloc[:,0:3])
#print(ipl.iloc[:,0:2])
print(ipl.iloc[:,[0,3,2]])


# print(ipl.iloc[1:3,0:3])
#print(ipl.iloc[1:3,[1,3]])
#print(ipl.iloc[[1,2,3],[1,3]])
# Out:
#    year  losses  wins
# 0    10       5    11
# 1    11       8     8
# 2    22       6    10
# 3    11       1    15
# 4    12       5    11
# 5    10      10     6
# 6    11       6    10
# 7    12      12     4
